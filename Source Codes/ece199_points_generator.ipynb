# %% [markdown]
# # **Random Points in the Grid Generation**
#
# ### RANDOM POSITION GENERATED/USED FOR THE TEST (6 INDIVIDUALS)
#
# Set  1 :  ['F8', 'F11', 'D8', 'L10', 'H3', 'E4'] &nbsp;&nbsp;&nbsp;&nbsp; Set  2 :  ['J7', 'G3', 'E9', 'I5', 'D7', 'L8']
#
# Set  3 :  ['F2', 'C6', 'F5', 'J4', 'L2', 'G6'] &nbsp;&nbsp;&nbsp;&nbsp; Set  4 :  ['C8', 'G10', 'B10', 'L8', 'D4', 'L9']
#
# Set  5 :  ['K4', 'D9', 'F7', 'B10', 'K7', 'L11'] &nbsp;&nbsp;&nbsp;&nbsp; Set  6 :  ['H10', 'C8', 'I2', 'I7', 'B12', 'K2']
#
# Set  7 :  ['I11', 'L6', 'C3', 'K7', 'E6', 'E10'] &nbsp;&nbsp;&nbsp;&nbsp; Set  8 :  ['J7', 'F3', 'J2', 'H2', 'K6', 'I12']
#
# Set  9 :  ['I4', 'F3', 'J2', 'F7', 'E10', 'I12'] &nbsp;&nbsp;&nbsp;&nbsp; Set  10 :  ['L7', 'L12', 'E8', 'E6', 'C12', 'E4']
#
#
# ### RANDOM POSITION GENERATED/USED FOR TEST (3 INDIVIDUALS)
#
# Set  1 :  ['F8', 'F11', 'D8'] &nbsp;&nbsp;&nbsp;&nbsp; Set  2 :  ['J7', 'G3', 'E9']
#
# Set  3 :  ['F2', 'C6', 'F5'] &nbsp;&nbsp;&nbsp;&nbsp; Set  4 :  ['C8', 'G10', 'B10']
#
# Set  5 :  ['K4', 'D9', 'F7'] &nbsp;&nbsp;&nbsp;&nbsp; Set  6 :  ['H10', 'C8', 'I2']
#
# Set  7 :  ['I11', 'L6', 'C3'] &nbsp;&nbsp;&nbsp;&nbsp; Set  8 :  ['J7', 'F3', 'J2']
#
# Set  9 :  ['I4', 'F3', 'J2'] &nbsp;&nbsp;&nbsp;&nbsp; Set  10 :  ['L7', 'L12', 'E8']
#
# #### OTHER POSITIONS (5 INDIVIDUALS)
#
# Set  1 :  ['F8', 'F11', 'D8', 'L10', 'H3'] &nbsp;&nbsp;&nbsp;&nbsp; Set  2 :  ['J7', 'G3', 'E9', 'I5', 'D7']
#
# Set  3 :  ['F2', 'C6', 'F5', 'J4', 'L2'] &nbsp;&nbsp;&nbsp;&nbsp; Set  4 :  ['C8', 'G10', 'B10', 'L8', 'D4']
#
# Set  5 :  ['K4', 'D9', 'F7', 'B10', 'K7'] &nbsp;&nbsp;&nbsp;&nbsp; Set  6 :  ['H10', 'C8', 'I2', 'I7', 'B12']
#
# Set  7 :  ['I11', 'L6', 'C3', 'K7', 'E6'] &nbsp;&nbsp;&nbsp;&nbsp; Set  8 :  ['J7', 'F3', 'J2', 'H2', 'K6']
#
# Set  9 :  ['I4', 'F3', 'J2', 'F7', 'E10'] &nbsp;&nbsp;&nbsp;&nbsp; Set  10 :  ['L7', 'L12', 'E8', 'E6', 'C12']
#
# #### OTHER POSITIONS (2 INDIVIDUALS)
#
# Set  1 :  ['F8', 'F11'] &nbsp;&nbsp;&nbsp;&nbsp; Set  2 :  ['J7', 'G3']
#
# Set  3 :  ['F2', 'C6'] &nbsp;&nbsp;&nbsp;&nbsp; Set  4 :  ['C8', 'G10']
#
# Set  5 :  ['K4', 'D9'] &nbsp;&nbsp;&nbsp;&nbsp; Set  6 :  ['H10', 'C8']
#
# Set  7 :  ['I11', 'L6'] &nbsp;&nbsp;&nbsp;&nbsp; Set  8 :  ['J7', 'F3']
#
# Set  9 :  ['I4', 'F3'] &nbsp;&nbsp;&nbsp;&nbsp;  Set  10 :  ['L7', 'L12']

# %%
import random

# Function to randomly pick a specified number of unique cells from the grid
def pick_random_cells(num_cells, side_cells):
    cells = set()  # Set to store unique cells
    while len(cells) < num_cells:
        letter = random.choice(string.ascii_uppercase[:13])
        number = random.randint(1, 13)
        cell = letter + str(number)
        if cell not in side_cells:  # Check if the cell is not in side_cells
            cells.add(cell)
    return list(cells)

'''
# Random Cell Points Generator
side_cells = ['A1', 'A2', 'A3', 'A4', 'A5', 'A6', 'A7', 'A8', 'A9', 'A10', 'A11', 'A12', 'A13', 'M1', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'M10', 'M11', 'M12', 'M13', 'B1', 'C1', 'D1', 'E1', 'F1', 'G1', 'H1', 'I1', 'J1', 'K1', 'L1', 'B13', 'C13', 'D13', 'E13', 'F13', 'G13', 'H13', 'I13', 'J13', 'K13', 'L13']
num_cells = 6  # Change this to the desired number of random cells
num_trials = 10  # Change this to the desired number of trials
cellset_6ind = []
cellset_3ind = []
for i in range(num_trials):
    random_cells = pick_random_cells(num_cells, side_cells)
    cellset_5ind.append(random_cells)
    cellset_3ind.append(random_cells[:3])

print("cellset_6ind: ", cellset_6ind)
print("cellset_3ind: ", cellset_3ind)
'''
# Out:
# '\n# Random Cell Points Generator\nside_cells = [\'A1\', \'A2\', \'A3\', \'A4\', \'A5\', \'A6\', \'A7\', \'A8\', \'A9\', \'A10\', \'A11\', \'A12\', \'A13\', \'M1\', \'M2\', \'M3\', \'M4\', \'M5\', \'M6\', \'M7\', \'M8\', \'M9\', \'M10\', \'M11\', \'M12\', \'M13\', \'B1\', \'C1\', \'D1\', \'E1\', \'F1\', \'G1\', \'H1\', \'I1\', \'J1\', \'K1\', \'L1\', \'B13\', \'C13\', \'D13\', \'E13\', \'F13\', \'G13\', \'H13\', \'I13\', \'J13\', \'K13\', \'L13\']\nnum_cells = 6  # Change this to the desired number of random cells\nnum_trials = 10  # Change this to the desired number of trials\ncellset_6ind = []\ncellset_3ind = []\nfor i in range(num_trials):\n    random_cells = pick_random_cells(num_cells, side_cells)\n    cellset_5ind.append(random_cells)\n    cellset_3ind.append(random_cells[:3])\n\nprint("cellset_6ind: ", cellset_6ind)\nprint("cellset_3ind: ", cellset_3ind)\n'

# %%
# RANDOM CELL SET USED
cellset_6ind = [['F8', 'F11', 'D8', 'L10', 'H3', 'E4'], ['J7', 'G3', 'E9', 'I5', 'D7', 'L8'], ['F2', 'C6', 'F5', 'J4', 'L2', 'G6'], ['C8', 'G10', 'B10', 'L8', 'D4', 'L9'], ['K4', 'D9', 'F7', 'B10', 'K7', 'L11'], ['H10', 'C8', 'I2', 'I7', 'B12', 'K2'], ['I11', 'L6', 'C3', 'K7', 'E6', 'E10'], ['J7', 'F3', 'J2', 'H2', 'K6', 'I12'], ['I4', 'F3', 'J2', 'F7', 'E10', 'I12'], ['L7', 'L12', 'E8', 'E6', 'C12', 'E4']]
cellset_5ind = [['F8', 'F11', 'D8', 'L10', 'H3'], ['J7', 'G3', 'E9', 'I5', 'D7'], ['F2', 'C6', 'F5', 'J4', 'L2'], ['C8', 'G10', 'B10', 'L8', 'D4'], ['K4', 'D9', 'F7', 'B10', 'K7'], ['H10', 'C8', 'I2', 'I7', 'B12'], ['I11', 'L6', 'C3', 'K7', 'E6'], ['J7', 'F3', 'J2', 'H2', 'K6'], ['I4', 'F3', 'J2', 'F7', 'E10'], ['L7', 'L12', 'E8', 'E6', 'C12']]
cellset_3ind = [['F8', 'F11', 'D8'], ['J7', 'G3', 'E9'], ['F2', 'C6', 'F5'], ['C8', 'G10', 'B10'], ['K4', 'D9', 'F7'], ['H10', 'C8', 'I2'], ['I11', 'L6', 'C3'], ['J7', 'F3', 'J2'], ['I4', 'F3', 'J2'], ['L7', 'L12', 'E8']]
cellset_2ind = [['F8', 'F11' ], ['J7', 'G3'], ['F2', 'C6'], ['C8', 'G10'], ['K4', 'D9'], ['H10', 'C8'], ['I11', 'L6'], ['J7', 'F3'], ['I4', 'F3'], ['L7', 'L12']]

# %%
import string

# Function to generate coordinates for a given cell label
def cell_to_coordinate(cell):
    # Extract row and column indices from the cell label
    column_index = string.ascii_uppercase.index(cell[0])
    row_index = int(cell[1:])-1

    # Calculate coordinates with (0,0) at the center
    x = (-6 + column_index) * 500
    y = (6 - row_index) * 500

    return (x, y)

# Create dictionary to map letters to coordinates
letter_to_coordinate = {}
for letter in string.ascii_uppercase[:13]:
    for i in range(1, 14):
        cell = letter + str(i)
        letter_to_coordinate[cell] = cell_to_coordinate(cell)

# Print letter to coordinate dictionary
print("Letter to Coordinate Dictionary:")
print(letter_to_coordinate)
for cell, coord in letter_to_coordinate.items():
    print(f"{cell} -> {coord}\n")
# Out:
# Letter to Coordinate Dictionary:
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

def rand_cell_plot(cellset):
    # Create a figure and axis
    fig, ax = plt.subplots(figsize=(5, 5))

    # Plot cell coordinates
    for cell in cellset:
        x, y = cell_to_coordinate(cell)
        ax.scatter(x, y, color='red', s=200, alpha=0.5)  # Adjust color and point diameter here


    # Set plot limits
    ax.set_xlim(-3000, 3000)
    ax.set_ylim(-3000, 3000)

    # Set aspect ratio to equal to maintain square cells
    ax.set_aspect('equal', adjustable='box')

    # Set major tick locator and formatter for both x and y axes
    ax.xaxis.set_major_locator(ticker.MultipleLocator(500))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(500))

    # Manually set tick labels for every other label to empty strings
    ax.xaxis.set_major_formatter(ticker.FuncFormatter(lambda x, _: '' if int(x) % 1000 != 0 else int(x)))
    ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda y, _: '' if int(y) % 1000 != 0 else int(y)))

    # Show grid lines
    ax.grid(True)

    # Show plot
    plt.show()

for cellset in cellset_2ind:
    rand_cell_plot(cellset)
